# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 645          646         1       1  Harper, Mr. Henry Sleeper  male  48.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 645      1      0  PC 17572  76.7292   D33        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# making data frame from csv file  
df = pd.read_csv("titanic.csv")

# %%
# generating one row  
row1 = df.sample(n = 1)
row1
# Out:
#      PassengerId  Survived  Pclass  \
# 506          507         1       2
#
#                                               Name     Sex   Age  SibSp  \
# 506  Quick, Mrs. Frederick Charles (Jane Richards)  female  33.0      0
#
#      Parch Ticket  Fare Cabin Embarked
# 506      2  26360  26.0   NaN        S

# %%
#Generating another row
row2 = df.sample(n = 1)

row2
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 362          363         0       3  Barbara, Mrs. (Catherine David)  female
#
#       Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 362  45.0      0      1   2691  14.4542   NaN        C

# %%
#This code uses pandas to read “nba.csv” and It then calculates and prints the total number of elements (size) in the DataFrame
size  = df.size

print("size = {}".format(size))
# Out:
# size = 10692

# %%
shape = df.shape

print("Shape = {}".format(shape))
# Out:
# Shape = (891, 12)

# %%
#dataframe.ndim
df_ndim = df.ndim

# %%
#series.ndim
series_ndim = df["Pclass"].ndim


#print ndim
print("ndim of dataframe = {}\ndim of series = {}".
        format(df_ndim, series_ndim))
# Out:
# ndim of dataframe = 2
# dim of series = 1

# %%
#Pandas DataFrame describe()
#Pandas describe() is used to view some basic statistical details like percentile, mean, std, etc. of a data frame or a series of numeric values

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# removing null values to avoid errors
df.dropna(inplace=True)

# %%
#list of dtypes to include
include = ['object', 'float', 'int']

# %%
# percentile list
perc = [.20, .40, .60, .80]
 
# calling describe method
desc = df.describe(percentiles=perc, include=include)

# %%
#importing pandas module

import pandas as pd
#Making data frame 
df = pd.read_csv("titanic.csv")
#removing null values to avoid errors
df.dropna(inplace=True)
#calling describe method
desc = df["Survived"].describe()
#display
desc
# Out:
# count    183.000000
# mean       0.672131
# std        0.470725
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# Using Series.unique()
# In this example, unique() method is used to know all type of unique values in Team column.

# %%
import pandas as pd

#making data frame from csv file
df = pd.read_csv("titanic.csv")

#storing unique value in a variable
arr = df["Pclass"].unique()

#printing array
print(arr)
# Out:
# [3 1 2]

# %%
#creating dataframe
df = pd.read_csv("titanic.csv")

#print the data frame

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# Use Series.value_counts() function to find the unique value counts of each element in the given Series object.

# %%
sr = pd.Series(['PassengerID', 'Pclass', 'Sex', 'Age','Survived'])

print(sr)
# Out:
# 0    PassengerID
# 1         Pclass
# 2            Sex
# 3            Age
# 4       Survived
# dtype: object

# %%
import pandas as pd 
df = pd.read_csv("titanic.csv")
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.expanding()
# Out:
# Expanding [min_periods=1,axis=0,method=single]

# %%
import numpy as np
import random

# %%
df.iloc[[1]]
# Out:
#       Col1      Col2      Col3     Col4
# 1  0.16453 -0.430096  0.767369  0.98492

# %%
df= pd.read_csv("titanic.csv")
df.rename(columns={'Pclass':'Passengerclass'},inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Passengerclass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
In[7]:df["Age"].max()
Out[7]:58

# %%
age_male = pd.read_csv("titanic.csv", index_col=0, parse_dates=True)
age_male.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19816\2636337571.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   age_male = pd.read_csv("titanic.csv", index_col=0, parse_dates=True)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
# Load data into a Pandas DataFrame
df = pd.read_csv("titanic.csv")

# Display the first few rows of the DataFrame
print(df.head())

# Basic visualization examples
# Example 1: Bar chart of the number of survivors vs non-survivors
survival_counts = df['Survived'].value_counts()
plt.figure(figsize=(8, 6))
survival_counts.plot(kind='bar', color=['red', 'green'])
plt.title('Survival Counts')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example 2: Histogram of ages
plt.figure(figsize=(10, 6))
plt.hist(df['Age'].dropna(), bins=30, edgecolor='k', alpha=0.7)
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
### For the barplot:

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("titanic.csv")

# Sample 100 rows
sampled_df = df.sample(n=100, random_state=42)

# Draw a nested barplot by PClass and Survived
g = sns.catplot(
    data=sampled_df, kind="bar",
    x="Pclass", y="Survived", hue="Sex",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Pclass", "Survived")
g.legend.set_title("")
plt.show()

# %%
# Load data for Cabin and Fare 

df = pd.read_csv("titanic.csv")

# Sample 100 rows
sampled_df = df.sample(n=60, random_state=42)

# Draw a nested barplot by PClass and Survived
g = sns.catplot(
    data=sampled_df, kind="bar",
    x="Cabin", y="Fare", hue="Sex",
    errorbar="sd", palette="dark", alpha=.4, height=6
)
g.despine(left=True)
g.set_axis_labels("Cabin", "Fare")
g.legend.set_title("")
plt.show()

# %%
# Load data
df = pd.read_csv("titanic.csv")

# Sample 100 rows
sampled_df = df.sample(n=100, random_state=42)

# Draw a nested barplot by PClass and Survived
g = sns.catplot(
    data=sampled_df, kind="bar",
    x="Pclass", y="Age", hue="Sex",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Pclass", "Sex")
g.legend.set_title("")
plt.show()

# %%
### For the pie chart:

# Sample 100 rows
sampled_df = df.sample(n=100, random_state=42)

# Count the Cabin values
cabin_counts = sampled_df['Cabin'].value_counts()

# Plot the pie chart
plt.figure(figsize=(10, 10))
cabin_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'silver', 'brown'])
plt.title('Cabin distribution of Passengers')
plt.ylabel('')
plt.show()

# %%
#If you want to show the full dataset but still ensure that the visualization is manageable and informative,
#you can use aggregation. Aggregation will summarize the data to show the overall trends without overwhelming the plot.
### Example: Aggregated Bar Plot

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("titanic.csv")

# Aggregate data: calculate the mean survival rate by Pclass and Sex
agg_df = df.groupby(['Pclass', 'Sex']).agg({'Survived': 'mean'}).reset_index()

# Draw a barplot with aggregated data
g = sns.catplot(
    data=agg_df, kind="bar",
    x="Pclass", y="Survived", hue="Sex",
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Pclass", "Survived (mean)")
g.legend.set_title("")
plt.show()

# %%
### Alternative Example: Using Count for Bar Plot

#use counts instead of mean survival rates, here's how you can do it:

python
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("titanic.csv")

# Aggregate data: count the number of survivors by Pclass and Sex
agg_df = df.groupby(['Pclass', 'Sex']).agg({'Survived': 'sum'}).reset_index()

# Draw a barplot with aggregated data
g = sns.catplot(
    data=agg_df, kind="bar",
    x="Pclass", y="Survived", hue="Sex",
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Pclass", "Number of Survivors")
g.legend.set_title("")
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
df = pd.read_csv("titanic.csv")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Age", y="Sex",
            hue="Survived", palette=["m", "g"],
            data=df)
sns.despine(offset=20, trim=True)
plt.show()
